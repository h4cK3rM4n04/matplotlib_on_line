# %% [markdown]
# # Exercice 1:
#
# Tracer un graphique en courbes des fonctions $f(x) = x$ et $g(x) = x^2$ pour x allant de -10 à 10.

# %%
#coding:utf-8 by h4cK3rM4n04
import matplotlib.pyplot as pyp
import numpy as num
def f(x):
    return x
def g(x):
    return x ** 2
fig , ax = pyp.subplots()
x = num.arange(-10,10)
y = f(x)
pyp.plot(x, y, label="f(x)")
y = g(x)
pyp.plot(x, y, label="g(x)")
pyp.legend()
pyp.xlabel("Axe des (x)")
pyp.ylabel("Axe des (y)")
ax.set_facecolor("lightblue")
ax.grid()
fig.set_facecolor("darkgrey")

# %% [markdown]
# # Exercice 2:
#
# Créer un histogramme représentant la distribution de la taille des animaux dans un zoo donné.

# %%
#coding:utf-8 by h4cK3rM4n04
import matplotlib.pyplot as pyp
figure, axe = pyp.subplots()
pyp.title("Distribiution des tailles des animaux")
pyp.xlabel("Animal size")
pyp.ylabel("Animal number(s)")
figure.set_facecolor("orange")
axe.set_facecolor("black")
axe.grid()
size = [1.5, 2, 4.75, 5, 1.65, 2.35, 4.99, 5.68, 6, 8, 10.1, 11]
pyp.hist(size, bins = 5, edgecolor = "red")
pyp.show()

# %% [markdown]
# # Exercice 3:
#
# Tracer un graphique en nuage de points représentant les ventes mensuelles de différents produits pour une entreprise donnée.

# %%
#coding:utf-8 by h4cK3rM4n04
import matplotlib.pyplot as pyp
import numpy as np
import random
pyp.subplot(2,2,1)
sale = {1: random.randint(0,1000), 2: random.randint(0,1000), 3:random.randint(0,1000),
        4: random.randint(0,1000),
       5: random.randint(0,1000), 6: random.randint(0,1000), 7: random.randint(0,1000),
        8: random.randint(0,1000),
        9: random.randint(0,1000)}
keys = [x for x in sale.keys()]
values = [x for x in sale.values()]
pyp.scatter(keys, values)
pyp.xlabel("Produits")
pyp.ylabel("Prix")
pyp.title("Prix de produit en 2000")
pyp.subplot(2,2,4)
sale = {1: random.randint(0,1000), 2: random.randint(0,1000), 3:random.randint(0,1000),
        4: random.randint(0,1000),
       5: random.randint(0,1000), 6: random.randint(0,1000), 7: random.randint(0,1000),
        8: random.randint(0,1000),
        9: random.randint(0,1000)}
keys = [x for x in sale.keys()]
values = [x for x in sale.values()]
pyp.scatter(keys, values)
pyp.xlabel("Produits")
pyp.ylabel("Prix")
pyp.title("Prix de produit en 2023")
pyp.show()

# %% [markdown]
# # Exercice 4:
#
# Créer un diagramme circulaire pour représenter les parts de marché de différentes entreprises dans un secteur donné.

# %%
#coding:utf-8 by h4cK3rM4n04
import matplotlib.pyplot as plt
import numpy as np
figure, axe = plt.subplots()
buisiness_market = {"apple": 50, "meta": 92, "android": 35, "openai": 85, "h4cK3rM4n04": 100}
x = [x for x in buisiness_market.values()]
y = [x for x in buisiness_market.keys()]
array = np.array(y)
plt.pie(x, labels = array, autopct = lambda x:f"{x:.1f}%",
       colors = ["yellow", "blue", "green", "lightblue", "red"])#lambda x:f"{x:.1f}%" cette ligne de code peut être remplacé par %1.1f%%
axe.legend(title = "Diagramme")
plt.show()

# %% [markdown]
# # Exercice 5:
#
# Tracer un graphique en barres représentant le nombre de personnes de différentes tranches d'âge dans une population donnée.

# %%
#coding:utf-8 by h4cK3rM4n04
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()
population = np.array(["Jin", "Heihachi", "Law", "Paul", "Xiaoyu"])
number_person = [2, 5, 4, 3, 7]
plt.bar(population, number_person, edgecolor = "red")
plt.title("Nombres de personnes de différentes tranches d'âge dans une population")
plt.xlabel("population")
plt.ylabel("Age de la population")
ax.set_facecolor("black")
fig.set_facecolor("lightgrey")
plt.show()
